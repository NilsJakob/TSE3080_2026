# %% [markdown]
# # TSE3080 Electrical Machines
#
# ## Why english?
#    The Norwegian Agency for Quality Assurance (Nasjonalt organ for kvalitet i utdanningen) NOKUT study in 2007
#    Improve internationalisation of engineering courses
#
#  - English text books ($\rightarrow$ passive learning)
#   - Courses partly in English ($\rightarrow$ active learning)
#    - Whole English semester
#
# Benefits:
#
# -  Prepared for study/work abroad or in international context
# - Study more attractive to foreign students
# - Improved job opportunities
# - Easier entry to Master level
#
#
# ### Lecture topics
#
#     - DC Machines
#     - Transformers
#     - Induction Machines (Asynchronous Machines)
#     - Synchronous Machines
#     - Single Phase Machines
#     - Electric Drives
#
# ##### Organisation
# All updates in [canvas](https://usn.instructure.com/courses/38049)
# - Lectures:
#  - Introduction: Nils Jakob
#  - Transformers \& Synchronous Machines: Jonas Nøland
#  - DC/AC Machines and Power Electronics: Sanjeevikumar Padmanaban
#
# Combined lectures and tutorials
# - Mondays
# - 08:15-12:00 Classroom Lecture in A-255
# - 12:15-14:00 Classroom Tutorial in A-255
# - Tuesdays
# - 14:15-16:00 Classroom Tutorial in A-195
#
# Timetable: [Timeedit_TSE3080](https://cloud.timeedit.net/usn/web/publikk/ri11Q604260017QQ51ZZ75y08cyYW34776d58704Q656h3Z6Qnk8bsnlc.html)

# %%
# TEST CELL
from IPython.display import IFrame

IFrame( src="https://use.mazemap.com/embed.html#v=1&amp;config=USN&amp;campusid=917&amp;zlevel=2&amp;center=9.672544,59.138621&amp;zoom=17.9&amp;desttype=poi&amp;dest=1001503086&amp;starttype=poi&amp;start=1001482396&amp;utm_medium=iframe", width=900, height=500 )
# Out:
#         <iframe
#             width="900"
#             height="500"
#             src="https://use.mazemap.com/embed.html#v=1&amp;config=USN&amp;campusid=917&amp;zlevel=2&amp;center=9.672544,59.138621&amp;zoom=17.9&amp;desttype=poi&amp;dest=1001503086&amp;starttype=poi&amp;start=1001482396&amp;utm_medium=iframe"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### LAB
# Laboratory organised by Terje Bergerud and Mohammad Yassin
# Tutorials: Mohammed Yassin
# ##### To be eligable for exam
# To be eligable for writtenexam and Synchronous LAB students must pass:
# ###### UniTrain LAB
# - TRAFO LAB
# - ASM LAB

# %%
# TEST CELL
from IPython.display import IFrame

IFrame( src="https://use.mazemap.com/#v=1&config=USN&campusid=917&zlevel=1&center=9.672734,59.138296&zoom=18.4&desttype=poi&dest=1001482355&starttype=poi&start=1001482396", width=900, height=500 )
# Out:
#         <iframe
#             width="900"
#             height="500"
#             src="https://use.mazemap.com/#v=1&config=USN&campusid=917&zlevel=1&center=9.672734,59.138296&zoom=18.4&desttype=poi&dest=1001482355&starttype=poi&start=1001482396"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Evaluation: 30\% laboratory and 70\% final exam\\
#
# ###### Time Budget
# about 270 Hours
# ###### Syllabus
#
#  -  Wildi(2021): Selected Chapters from Theodore Wildi:
# “Electrical Machines, Drives, and Power Systems”.
#
# Alternatively:
# - Wildi(2014): Electrical Machines, Drives, and Power Systems., 6th edition (reprint)
# - Wildi(2006): Electrical Machines, Drives, and Power Systems., 6th edition
#
# ![wildi](../images/frontpage.png)
